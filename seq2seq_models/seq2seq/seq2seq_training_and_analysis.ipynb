# %% [markdown]
# # Imports

# %%
# !pip install git+https://github.com/AlvaroJoseLopes/sequence2sequence-models
# !pip install spacy -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/AlvaroJoseLopes/sequence2sequence-models
#   Cloning https://github.com/AlvaroJoseLopes/sequence2sequence-models to /tmp/pip-req-build-w3vcvc7d
#   Running command git clone --filter=blob:none --quiet https://github.com/AlvaroJoseLopes/sequence2sequence-models /tmp/pip-req-build-w3vcvc7d
#   Resolved https://github.com/AlvaroJoseLopes/sequence2sequence-models to commit b42cbeddf7e19ebac29e039edb02060ad3d87edc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from seq2seq-models==0.0.1) (1.13.1+cu116)
# Requirement already satisfied: torchtext in /usr/local/lib/python3.8/dist-packages (from seq2seq-models==0.0.1) (0.14.1)
# Collecting torchdata
#   Downloading torchdata-0.5.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 35.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->seq2seq-models==0.0.1) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchdata->seq2seq-models==0.0.1) (2.25.1)
# Collecting urllib3>=1.25
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 12.3 MB/s eta 0:00:00
# Collecting portalocker>=2.0.0
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext->seq2seq-models==0.0.1) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext->seq2seq-models==0.0.1) (1.21.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchdata->seq2seq-models==0.0.1) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchdata->seq2seq-models==0.0.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchdata->seq2seq-models==0.0.1) (4.0.0)
# Building wheels for collected packages: seq2seq-models
#   Building wheel for seq2seq-models (setup.py) ... done
#   Created wheel for seq2seq-models: filename=seq2seq_models-0.0.1-py3-none-any.whl size=8967 sha256=56e6372f32c69b57b864c553c78087a3e01d895100e1ec5976882494e5867e57
#   Stored in directory: /tmp/pip-ephem-wheel-cache-faksxu6o/wheels/1c/7d/fa/bed29ef3b79ad38318eb71f5111a30d2cf83d66ba77101c01e
# Successfully built seq2seq-models
# Installing collected packages: urllib3, portalocker, torchdata, seq2seq-models
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed portalocker-2.7.0 seq2seq-models-0.0.1 torchdata-0.5.1 urllib3-1.26.14
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Collecting spacy
#   Downloading spacy-3.5.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.11)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.5.0 which is incompatible.
# Successfully installed spacy-3.5.0

# %%
# !python -m spacy download de_core_news_sm
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting de-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.5.0/de_core_news_sm-3.5.0-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.8/dist-packages (from de-core-news-sm==3.5.0) (3.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (2.25.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (1.10.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (8.1.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (2.4.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (3.0.11)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->de-core-news-sm==3.5.0) (2.0.1)
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 79.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.5.0) (3.5.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.11)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.25.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (57.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.4.1
#     Uninstalling en-core-web-sm-3.4.1:
#       Successfully uninstalled en-core-web-sm-3.4.1
# Successfully installed en-core-web-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Training model

# %%
# !mkdir models/

# %%
from seq2seq_models import seq2seq
seq2seq.train_model_script(
    ('-src', 'en',
     '-trg', 'de',
     '-f', 'models/model_20_12300.pt',
     '-ep', '20',
     '-bs', '128',
     '-s', '12300')
)
# Out:
# Chosen device cuda
# /usr/local/lib/python3.8/dist-packages/torchtext/data/utils.py:105: UserWarning: Spacy model "en" could not be loaded, trying "en_core_web_sm" instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchtext/data/utils.py:105: UserWarning: Spacy model "de" could not be loaded, trying "de_core_news_sm" instead
#   warnings.warn(
# Source vocab size: 10837
# target vocab size: 19214
# The model has 24,906,254 trainable parameters
# Epoch: 01
# 	Time: 1m 16s
# 	Train Loss: 5.553 | Train PPL: 257.925
# 	 Val. Loss: 5.610 |  Val. PPL: 273.164
# Epoch: 02
# 	Time: 1m 16s
# 	Train Loss: 4.965 | Train PPL: 143.344
# 	 Val. Loss: 5.615 |  Val. PPL: 274.500
# Epoch: 03
# 	Time: 1m 17s
# 	Train Loss: 4.619 | Train PPL: 101.402
# 	 Val. Loss: 5.352 |  Val. PPL: 211.120
# Epoch: 04
# 	Time: 1m 16s
# 	Train Loss: 4.298 | Train PPL:  73.565
# 	 Val. Loss: 5.173 |  Val. PPL: 176.446
# Epoch: 05
# 	Time: 1m 16s
# 	Train Loss: 4.085 | Train PPL:  59.466
# 	 Val. Loss: 5.037 |  Val. PPL: 153.994
# Epoch: 06
# 	Time: 1m 15s
# 	Train Loss: 3.883 | Train PPL:  48.559
# 	 Val. Loss: 4.985 |  Val. PPL: 146.259
# Epoch: 07
# 	Time: 1m 16s
# 	Train Loss: 3.723 | Train PPL:  41.407
# 	 Val. Loss: 4.858 |  Val. PPL: 128.813
# Epoch: 08
# 	Time: 1m 16s
# 	Train Loss: 3.546 | Train PPL:  34.691
# 	 Val. Loss: 4.810 |  Val. PPL: 122.719
# Epoch: 09
# 	Time: 1m 16s
# 	Train Loss: 3.393 | Train PPL:  29.754
# 	 Val. Loss: 4.735 |  Val. PPL: 113.916
# Epoch: 10
# 	Time: 1m 15s
# 	Train Loss: 3.224 | Train PPL:  25.119
# 	 Val. Loss: 4.785 |  Val. PPL: 119.659
# Epoch: 11
# 	Time: 1m 17s
# 	Train Loss: 3.096 | Train PPL:  22.112
# 	 Val. Loss: 4.719 |  Val. PPL: 112.020
# Epoch: 12
# 	Time: 1m 16s
# 	Train Loss: 2.946 | Train PPL:  19.023
# 	 Val. Loss: 4.744 |  Val. PPL: 114.943
# Epoch: 13
# 	Time: 1m 17s
# 	Train Loss: 2.843 | Train PPL:  17.166
# 	 Val. Loss: 4.662 |  Val. PPL: 105.796
# Epoch: 14
# 	Time: 1m 16s
# 	Train Loss: 2.702 | Train PPL:  14.907
# 	 Val. Loss: 4.691 |  Val. PPL: 108.920
# Epoch: 15
# 	Time: 1m 17s
# 	Train Loss: 2.591 | Train PPL:  13.340
# 	 Val. Loss: 4.725 |  Val. PPL: 112.721
# Epoch: 16
# 	Time: 1m 17s
# 	Train Loss: 2.497 | Train PPL:  12.145
# 	 Val. Loss: 4.719 |  Val. PPL: 112.100
# Epoch: 17
# 	Time: 1m 17s
# 	Train Loss: 2.397 | Train PPL:  10.986
# 	 Val. Loss: 4.711 |  Val. PPL: 111.116
# Epoch: 18
# 	Time: 1m 17s
# 	Train Loss: 2.284 | Train PPL:   9.811
# 	 Val. Loss: 4.765 |  Val. PPL: 117.316
# Epoch: 19
# 	Time: 1m 17s
# 	Train Loss: 2.203 | Train PPL:   9.052
# 	 Val. Loss: 4.790 |  Val. PPL: 120.334
# Epoch: 20
# 	Time: 1m 17s
# 	Train Loss: 2.102 | Train PPL:   8.184
# 	 Val. Loss: 4.795 |  Val. PPL: 120.935

# %% [markdown]
# # Avaliando embeddings das palavras

# %%
import torch
import pandas as pd
model = torch.load('models/model_20_12300.pt')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Encoder

# %%
word_emb_en = seq2seq.get_word_embeddings(model, 'encoder', 'en', device)

# %%
# # temp
# lang_vocab = torch.load('vocabs/vocab_en.pth')
# matrix = model.get_embeddings_matrix('encoder').cpu().detach().numpy()
# word_embeddings = {}
# for token, embedding in enumerate(list(matrix)):
#     word_embeddings[lang_vocab.lookup_token(token)] = embedding
df_emb_en = pd.DataFrame.from_dict(word_emb_en, orient='index')

# %%
df_emb_en.shape
# Out:
# (10837, 256)

# %%
df_emb_en.head()
# Out:
#             0         1         2         3         4         5         6    \
# <unk>  0.063939 -0.028902  0.056993  0.076601 -0.005598 -0.024722  0.068028
# <pad>  0.058660  0.239833 -0.035555 -0.170709 -0.210485 -0.218883  0.109745
# <bos>  0.073603  0.005235  0.040608 -0.048532 -0.029372  0.040548 -0.067014
# <eos>  0.125751  0.078651 -0.101203 -0.030379 -0.029018  0.058500  0.014182
# Two    0.124675 -0.169449  0.019475 -0.291517  0.422929  0.057474 -0.120621
#
#             7         8         9    ...       246       247       248  \
# <unk> -0.009198 -0.030310  0.011572  ...  0.048634 -0.067992 -0.042325
# <pad>  0.252079 -0.038930 -0.094167  ...  0.046578 -0.041479 -0.242284
# <bos>  0.033744 -0.014146  0.003455  ...  0.016210  0.031562 -0.101972
# <eos> -0.018485  0.160569  0.025618  ...  0.014636 -0.102945  0.041264
# Two   -0.175962  0.069835  0.070374  ... -0.197916  0.099323 -0.238502
#
#             249       250       251       252       253       254       255
# <unk> -0.008926 -0.054196 -0.060672 -0.038773 -0.076559  0.031633  0.001078
# <pad> -0.029043 -0.116294  0.235391 -0.149840 -0.186665  0.003605  0.071332
# <bos>  0.013369  0.118312 -0.009319  0.036025  0.010091  0.027375 -0.011889
# <eos> -0.021797  0.028537  0.068015 -0.128520  0.067708 -0.026905 -0.165524
# Two    0.150075  0.256969  0.209667  0.189067  0.131754  0.026992 -0.065954
#
# [5 rows x 256 columns]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(metric = 'cosine')
sample = df_emb_en.sample(2000)
reducedWordVecs = tsne.fit_transform(sample)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(

# %%
emb_reduced = {}
for idx, token in enumerate(sample.index):
  emb_reduced[token] = reducedWordVecs[idx]
df_emb_reduced = pd.DataFrame.from_dict(
        data = emb_reduced,
        orient = 'index',
        columns = ['x', 'y']
    )
df_emb_reduced['word'] = df_emb_reduced.index
df_emb_reduced.head()
# Out:
#                    x          y       word
# moutnain   -2.837571 -12.480426   moutnain
# bulb       15.033087  13.327866       bulb
# labels     11.850100 -13.234209     labels
# turbulent   4.304204  20.809372  turbulent
# 2012      -14.791627  -5.995130       2012

# %%
# Configurando a ferramenta interativa com o notebook
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()

def interativePlot(df, title = None, xlabel = None, ylabel = None):
    # Instancia uma ColumnDAtaSource do Bokeh usando o dataframe
    data = ColumnDataSource(df)

    # Cria o plot e configura:
    # título, dimensões e ferramentas interativas
    plot = figure(
        title= title,
        plot_width=800,
        plot_height=800,
        tools=(
            'pan, wheel_zoom, box_zoom,'
            'box_select, reset',
            HoverTool(tooltips = '@word')
            ),
        active_scroll='wheel_zoom',
        x_axis_label = xlabel,
        y_axis_label = ylabel
        )

    # Desenha os circulos representado as palavras
    plot.circle(
        'x',
        'y',
        source=data,
        color='blue',
        line_alpha=0.2,
        fill_alpha=0.1,
        size=10,
        hover_line_color='black'
        )

    # Configuração de outros detalhes visuais
    plot.xaxis.visible = False
    plot.yaxis.visible = False
    plot.grid.grid_line_color = None
    plot.outline_line_color = None


    show(plot)

# %%
interativePlot(df_emb_reduced)
# Out:
#   <div class="bk-root" id="aef6161b-05a0-416b-b0fe-c682a720e9e6" data-root-id="1004"></div>

# %% [markdown]
# ## Decoder

# %%
word_emb_de = seq2seq.get_word_embeddings(model, 'decoder', 'de', device)
df_emb_de = pd.DataFrame.from_dict(word_emb_de, orient='index')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(metric = 'cosine')
sample = df_emb_de.sample(2000)
reducedWordVecs = tsne.fit_transform(sample)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(

# %%
emb_reduced = {}
for idx, token in enumerate(sample.index):
  emb_reduced[token] = reducedWordVecs[idx]
df_emb_reduced = pd.DataFrame.from_dict(
        data = emb_reduced,
        orient = 'index',
        columns = ['x', 'y']
    )
df_emb_reduced['word'] = df_emb_reduced.index
df_emb_reduced.head()
# Out:
#                       x          y          word
# Großmütter    -4.613369  -7.088357    Großmütter
# Halbschatten  13.364667   9.243718  Halbschatten
# Falken         5.289365  15.588497        Falken
# seines       -24.990513  -4.246313        seines
# abgelenkt     19.753290   0.869905     abgelenkt

# %%
interativePlot(df_emb_reduced)
# Out:
#   <div class="bk-root" id="3b10cbe4-8a6c-42a3-a814-5e9baea9a25e" data-root-id="1110"></div>

# %% [markdown]
# # Avaliando embedding das sentencas

# %% [markdown]
# ## Exemplo 1

# %%
examples = ['Mary admires John',
 'Mary is in love with John',
 'Mary respects John',
 'John admires Mary',
 'John is in love with Mary',
 'John respects Mary']

# %%
h,c = seq2seq.get_sentences_embeddings(model, examples, 'en', device)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchtext/data/utils.py:105: UserWarning: Spacy model "en" could not be loaded, trying "en_core_web_sm" instead
#   warnings.warn(

# %%
sentences_emb = ((h+c)/2).mean(0)
sentences_emb = sentences_emb.cpu().detach().numpy()
sentences_emb.shape
# Out:
# (6, 512)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(metric = 'cosine')
reduced_sentences_emb = tsne.fit_transform(sentences_emb)
reduced_sentences_emb.shape
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# (6, 2)

# %%
sentences_emb = {}
for idx, sentence in enumerate(examples):
  sentences_emb[sentence] = reduced_sentences_emb[idx]
df_sentences_emb = pd.DataFrame.from_dict(data=sentences_emb, columns=['x', 'y'], orient='index')

# %%
df_sentences_emb['word'] = df_sentences_emb.index
df_sentences_emb.head()
# Out:
#                                     x           y                       word
# Mary admires John           -8.091329   62.217793          Mary admires John
# Mary is in love with John   26.029047 -115.752205  Mary is in love with John
# Mary respects John          68.931564  226.243515         Mary respects John
# John admires Mary         -140.291473  186.148941          John admires Mary
# John is in love with Mary -166.802856  -25.228626  John is in love with Mary

# %%
interativePlot(df_sentences_emb)
# Out:
#   <div class="bk-root" id="4f882b2a-bf86-4724-bc9b-9bcaa3d2f381" data-root-id="1227"></div>

# %% [markdown]
# ## Exemplo 2

# %%
examples = ['I was given a card by her in the garden',
 'In the garden , she gave me a card',
 'She gave me a card in the garden',
 'She was given a card by me in the garden',
 'In the garden , I gave her a card',
 'I gave her a card in the garden']

# %%
h,c = seq2seq.get_sentences_embeddings(model, examples, 'en', device)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchtext/data/utils.py:105: UserWarning: Spacy model "en" could not be loaded, trying "en_core_web_sm" instead
#   warnings.warn(

# %%
sentences_emb = ((h+c)/2).mean(0)
sentences_emb = sentences_emb.cpu().detach().numpy()
sentences_emb.shape
# Out:
# (6, 512)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(metric = 'cosine')
reduced_sentences_emb = tsne.fit_transform(sentences_emb)
reduced_sentences_emb.shape
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# (6, 2)

# %%
sentences_emb = {}
for idx, sentence in enumerate(examples):
  sentences_emb[sentence] = reduced_sentences_emb[idx]
df_sentences_emb = pd.DataFrame.from_dict(data=sentences_emb, columns=['x', 'y'], orient='index')

# %%
df_sentences_emb['word'] = df_sentences_emb.index
df_sentences_emb.head()
# Out:
#                                                    x           y  \
# I was given a card by her in the garden  -193.406158  -98.960007
# In the garden , she gave me a card        196.171844  129.093994
# She gave me a card in the garden           21.613659  -30.440687
# She was given a card by me in the garden  197.516846 -118.057922
# In the garden , I gave her a card        -111.999184  147.692154
#
#                                                                               word
# I was given a card by her in the garden    I was given a card by her in the garden
# In the garden , she gave me a card              In the garden , she gave me a card
# She gave me a card in the garden                  She gave me a card in the garden
# She was given a card by me in the garden  She was given a card by me in the garden
# In the garden , I gave her a card                In the garden , I gave her a card

# %%
interativePlot(df_sentences_emb)
# Out:
#   <div class="bk-root" id="78d35cc5-1975-4969-87d5-4918355d2414" data-root-id="1355"></div>
